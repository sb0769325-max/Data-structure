# %%
import pandas as pd

# %%
df=pd.read_csv("Student.csv")
print(df)
# Out:
#    Rollno    Name Department  Marks
# 0     101    Arun        CSE     85
# 1     102   priya         AI     88
# 2     103  Balaji         CS     90
# 3     104  Ananth         IT     90

# %%
df.head()
# Out:
#    Rollno    Name Department  Marks
# 0     101    Arun        CSE     85
# 1     102   priya         AI     88
# 2     103  Balaji         CS     90
# 3     104  Ananth         IT     90

# %%
print(df.shape)
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rollno      4 non-null      int64
#  1   Name        4 non-null      object
#  2   Department  4 non-null      object
#  3   Marks       4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
df.describe()
# Out:
#            Rollno      Marks
# count    4.000000   4.000000
# mean   102.500000  88.250000
# std      1.290994   2.362908
# min    101.000000  85.000000
# 25%    101.750000  87.250000
# 50%    102.500000  89.000000
# 75%    103.250000  90.000000
# max    104.000000  90.000000

# %%
print(df.loc[1])
# Out:
# Rollno          102
# Name          priya
# Department       AI
# Marks            88
# Name: 1, dtype: object

# %%
print(df.iloc[2])
# Out:
# Rollno           103
# Name          Balaji
# Department        CS
# Marks             90
# Name: 2, dtype: object

# %%
df["Grade"]=["A","A+","B","A"]
print(df)
# Out:
#    Rollno    Name Department  Marks Grade
# 0     101    Arun        CSE     85     A
# 1     102   priya         AI     88    A+
# 2     103  Balaji         CS     90     B
# 3     104  Ananth         IT     90     A

# %%
df["Marks"]=df["Marks"]+5
print(df)
# Out:
#    Rollno    Name Department  Marks Grade
# 0     101    Arun        CSE     90     A
# 1     102   priya         AI     93    A+
# 2     103  Balaji         CS     95     B
# 3     104  Ananth         IT     95     A
