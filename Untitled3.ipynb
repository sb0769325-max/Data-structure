# %%
import pandas as pd

# %%
df=pd.read_csv("Documents/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           NaN          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4            True        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    3
# sepal_width     3
# petal_length    3
# petal_width     0
# class           0
# dtype: int64

# %%
df['sepal_width']=df['sepal_width'].fillna(0.2)

# %%
df.isnull().sum()
# Out:
# sepal_length    3
# sepal_width     0
# petal_length    3
# petal_width     0
# class           0
# dtype: int64

# %%
mn=df['sepal_length'].mean()
mn
# Out:
# np.float64(5.861224489795918)

# %%
df['sepal_width']=df['sepal_width'].fillna(mn)

# %%
df.isnull().sum()
# Out:
# sepal_length    3
# sepal_width     0
# petal_length    3
# petal_width     0
# class           0
# dtype: int64

# %%
ma=df["petal_length"].median()
ma
# Out:
# 4.4

# %%
ma=df["petal_width"]=df["petal_width"].fillna(ma)

# %%
df.isnull().sum()
# Out:
# sepal_length    3
# sepal_width     0
# petal_length    3
# petal_width     0
# class           0
# dtype: int64
